# %%
# Import dependencies
import pandas as pd

# %% [markdown]
# ### Contacts DataFrame
# ---
# **Create a Contacts DataFrame that has the following columns:**
# - A column named "contact_id"  that contains the unique number of the contact person.
# - A column named "first_name" that contains the first name of the contact person.
# - A column named "last_name" that contains the first name of the contact person.
# - A column named "email" that contains the email address of the contact person
#
# Then export the DataFrame as a `contacts.csv` CSV file.

# %%
pd.set_option('max_colwidth', 400)

# %%
# Read the data into a Pandas DataFrame
contact_info_df = pd.read_excel('contacts.xlsx', header=3)
contact_info_df.head()
# Out:
#             contact_id                          name  \
# 0  {"contact_id": 4661     "name": "Cecilia Velasco"
# 1  {"contact_id": 3765       "name": "Mariana Ellis"
# 2  {"contact_id": 4187         "name": "Sofie Woods"
# 3  {"contact_id": 4941   "name": "Jeanette Iannotti"
# 4  {"contact_id": 2199      "name": "Samuel Sorgatz"
#
#                                        email
# 0   "email": "cecilia.velasco@rodrigues.fr"}
# 1        "email": "mariana.ellis@rossi.org"}
# 2        "email": "sofie.woods@riviere.com"}
# 3    "email": "jeanette.iannotti@yahoo.com"}
# 4       "email": "samuel.sorgatz@gmail.com"}

# %% [markdown]
# ### Use Pandas to extract the contact data.

# %%
contact_info_df.columns
# Out:
# Index(['contact_id', 'name', 'email'], dtype='object')

# %%
# Iterate through the contact_info_df and convert each row to a dictionary.
import json
contact_info_df.to_dict(orient='records')

    # Iterate through each dictionary (row) and get the values for each row using list comprehension.

    # Append the list of values for each row to a list. 
    

# Print out the list of values for each row.
# Out:
# [{'contact_id': '{"contact_id": 4661',
#   'name': ' "name": "Cecilia Velasco"',
#   'email': ' "email": "cecilia.velasco@rodrigues.fr"}'},
#  {'contact_id': '{"contact_id": 3765',
#   'name': ' "name": "Mariana Ellis"',
#   'email': ' "email": "mariana.ellis@rossi.org"}'},
#  {'contact_id': '{"contact_id": 4187',
#   'name': ' "name": "Sofie Woods"',
#   'email': ' "email": "sofie.woods@riviere.com"}'},
#  {'contact_id': '{"contact_id": 4941',
#   'name': ' "name": "Jeanette Iannotti"',
#   'email': ' "email": "jeanette.iannotti@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 2199',
#   'name': ' "name": "Samuel Sorgatz"',
#   'email': ' "email": "samuel.sorgatz@gmail.com"}'},
#  {'contact_id': '{"contact_id": 5650',
#   'name': ' "name": "Socorro Luna"',
#   'email': ' "email": "socorro.luna@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 5889',
#   'name': ' "name": "Carolina Murray"',
#   'email': ' "email": "carolina.murray@knight.com"}'},
#  {'contact_id': '{"contact_id": 4842',
#   'name': ' "name": "Kayla Moon"',
#   'email': ' "email": "kayla.moon@yahoo.de"}'},
#  {'contact_id': '{"contact_id": 3280',
#   'name': ' "name": "Ariadna Geisel"',
#   'email': ' "email": "ariadna.geisel@rangel.com"}'},
#  {'contact_id': '{"contact_id": 5468',
#   'name': ' "name": "Danielle Ladeck"',
#   'email': ' "email": "danielle.ladeck@scalfaro.net"}'},
#  {'contact_id': '{"contact_id": 3064',
#   'name': ' "name": "Tatiana Thompson"',
#   'email': ' "email": "tatiana.thompson@hunt.net"}'},
#  {'contact_id': '{"contact_id": 4904',
#   'name': ' "name": "Caleb Benavides"',
#   'email': ' "email": "caleb.benavides@rubio.com"}'},
#  {'contact_id': '{"contact_id": 1299',
#   'name': ' "name": "Sandra Hardy"',
#   'email': ' "email": "sandra.hardy@web.de"}'},
#  {'contact_id': '{"contact_id": 5602',
#   'name': ' "name": "Lotti Morris"',
#   'email': ' "email": "lotti.morris@yahoo.co.uk"}'},
#  {'contact_id': '{"contact_id": 5753',
#   'name': ' "name": "Reinhilde White"',
#   'email': ' "email": "reinhilde.white@voila.fr"}'},
#  {'contact_id': '{"contact_id": 4495',
#   'name': ' "name": "Kerry Patel"',
#   'email': ' "email": "kerry.patel@hutchinson.com"}'},
#  {'contact_id': '{"contact_id": 4269',
#   'name': ' "name": "Sophie Antoine"',
#   'email': ' "email": "sophie.antoine@andersen.com"}'},
#  {'contact_id': '{"contact_id": 2226',
#   'name': ' "name": "Martha Girard"',
#   'email': ' "email": "martha.girard@web.de"}'},
#  {'contact_id': '{"contact_id": 1558',
#   'name': ' "name": "Stephanie King"',
#   'email': ' "email": "stephanie.king@cervantes.com"}'},
#  {'contact_id': '{"contact_id": 2307',
#   'name': ' "name": "Amanda Palmer"',
#   'email': ' "email": "amanda.palmer@didier.fr"}'},
#  {'contact_id': '{"contact_id": 2900',
#   'name': ' "name": "Lina Alcala"',
#   'email': ' "email": "lina.alcala@vespa.net"}'},
#  {'contact_id': '{"contact_id": 5695',
#   'name': ' "name": "Itzel Murphy"',
#   'email': ' "email": "itzel.murphy@muelichen.de"}'},
#  {'contact_id': '{"contact_id": 5708',
#   'name': ' "name": "Filippo Parry"',
#   'email': ' "email": "filippo.parry@live.com"}'},
#  {'contact_id': '{"contact_id": 1663',
#   'name': ' "name": "Katelyn Cole"',
#   'email': ' "email": "katelyn.cole@fiebig.com"}'},
#  {'contact_id': '{"contact_id": 3605',
#   'name': ' "name": "Brian Novak"',
#   'email': ' "email": "brian.novak@ford.net"}'},
#  {'contact_id': '{"contact_id": 4678',
#   'name': ' "name": "Cilly Gay"',
#   'email': ' "email": "cilly.gay@callegaro.it"}'},
#  {'contact_id': '{"contact_id": 2251',
#   'name': ' "name": "Yolanda Snyder"',
#   'email': ' "email": "yolanda.snyder@gmx.de"}'},
#  {'contact_id': '{"contact_id": 6202',
#   'name': ' "name": "Evelin Odonnell"',
#   'email': ' "email": "evelin.odonnell@ibarra.net"}'},
#  {'contact_id': '{"contact_id": 3715',
#   'name': ' "name": "Ingeborg Alba"',
#   'email': ' "email": "ingeborg.alba@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 4242',
#   'name': ' "name": "Marina Madrid"',
#   'email': ' "email": "marina.madrid@galarza-alba.com"}'},
#  {'contact_id': '{"contact_id": 4326',
#   'name': ' "name": "Sheila Goodwin"',
#   'email': ' "email": "sheila.goodwin@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 5560',
#   'name': ' "name": "Valeria Rich"',
#   'email': ' "email": "valeria.rich@turchetta-mondadori.it"}'},
#  {'contact_id': '{"contact_id": 4002',
#   'name': ' "name": "Dustin Camacho"',
#   'email': ' "email": "dustin.camacho@rhodes.org.au"}'},
#  {'contact_id': '{"contact_id": 3813',
#   'name': ' "name": "Amalia Marenzio"',
#   'email': ' "email": "amalia.marenzio@grupo.com"}'},
#  {'contact_id': '{"contact_id": 5336',
#   'name': ' "name": "Gian Long"',
#   'email': ' "email": "gian.long@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 4994',
#   'name': ' "name": "Stewart Hunt"',
#   'email': ' "email": "stewart.hunt@anderson-vargas.biz"}'},
#  {'contact_id': '{"contact_id": 1471',
#   'name': ' "name": "Greca Ruiz"',
#   'email': ' "email": "greca.ruiz@carr.co.uk"}'},
#  {'contact_id': '{"contact_id": 4482',
#   'name': ' "name": "Gerald Olivera"',
#   'email': ' "email": "gerald.olivera@outlook.com"}'},
#  {'contact_id': '{"contact_id": 3241',
#   'name': ' "name": "Jaqueline Wallace"',
#   'email': ' "email": "jaqueline.wallace@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3477',
#   'name': ' "name": "John Lane"',
#   'email': ' "email": "john.lane@gregoire.fr"}'},
#  {'contact_id': '{"contact_id": 2265',
#   'name': ' "name": "Pero Joly"',
#   'email': ' "email": "pero.joly@bernard.net"}'},
#  {'contact_id': '{"contact_id": 5911',
#   'name': ' "name": "Chad Turner"',
#   'email': ' "email": "chad.turner@gmail.com"}'},
#  {'contact_id': '{"contact_id": 2288',
#   'name': ' "name": "Adam Zavala"',
#   'email': ' "email": "adam.zavala@guichard.fr"}'},
#  {'contact_id': '{"contact_id": 4064',
#   'name': ' "name": "Tyler Rivera"',
#   'email': ' "email": "tyler.rivera@guajardo-ozuna.com"}'},
#  {'contact_id': '{"contact_id": 1294',
#   'name': ' "name": "Jens Graham"',
#   'email': ' "email": "jens.graham@jones-buckley.com"}'},
#  {'contact_id': '{"contact_id": 5008',
#   'name': ' "name": "Virginia Caetani"',
#   'email': ' "email": "virginia.caetani@sosa.biz"}'},
#  {'contact_id': '{"contact_id": 3604',
#   'name': ' "name": "Martino Wagner"',
#   'email': ' "email": "martino.wagner@laposte.net"}'},
#  {'contact_id': '{"contact_id": 3263',
#   'name': ' "name": "Martin Meyer"',
#   'email': ' "email": "martin.meyer@davis.co.uk"}'},
#  {'contact_id': '{"contact_id": 5631',
#   'name': ' "name": "Marguerite Walls"',
#   'email': ' "email": "marguerite.walls@martinez.fr"}'},
#  {'contact_id': '{"contact_id": 2851',
#   'name': ' "name": "Peter Vogt"',
#   'email': ' "email": "peter.vogt@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 3714',
#   'name': ' "name": "Nicholas Christian"',
#   'email': ' "email": "nicholas.christian@hotmail.de"}'},
#  {'contact_id': '{"contact_id": 1664',
#   'name': ' "name": "Susi Steinberg"',
#   'email': ' "email": "susi.steinberg@preiss.com"}'},
#  {'contact_id': '{"contact_id": 5027',
#   'name': ' "name": "Tammy Ramazzotti"',
#   'email': ' "email": "tammy.ramazzotti@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3070',
#   'name': ' "name": "Abdul Thomas"',
#   'email': ' "email": "abdul.thomas@vasari.com"}'},
#  {'contact_id': '{"contact_id": 4248',
#   'name': ' "name": "Justin Luxardo"',
#   'email': ' "email": "justin.luxardo@googlemail.com"}'},
#  {'contact_id': '{"contact_id": 2034',
#   'name': ' "name": "Antonio Gibson"',
#   'email': ' "email": "antonio.gibson@faust.net"}'},
#  {'contact_id': '{"contact_id": 4085',
#   'name': ' "name": "Jeremy Gomez"',
#   'email': ' "email": "jeremy.gomez@oconnor.org"}'},
#  {'contact_id': '{"contact_id": 3569',
#   'name': ' "name": "Raymond Solorzano"',
#   'email': ' "email": "raymond.solorzano@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3889',
#   'name': ' "name": "Flora Harris"',
#   'email': ' "email": "flora.harris@hotmail.com.au"}'},
#  {'contact_id': '{"contact_id": 3136',
#   'name': ' "name": "Cheryl Boyd"',
#   'email': ' "email": "cheryl.boyd@segni.it"}'},
#  {'contact_id': '{"contact_id": 2103',
#   'name': ' "name": "Rhys Leiva"',
#   'email': ' "email": "rhys.leiva@gmx.de"}'},
#  {'contact_id': '{"contact_id": 2329',
#   'name': ' "name": "Mariano Prieto"',
#   'email': ' "email": "mariano.prieto@vodafone.it"}'},
#  {'contact_id': '{"contact_id": 3325',
#   'name': ' "name": "Laurie Fibonacci"',
#   'email': ' "email": "laurie.fibonacci@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3131',
#   'name': ' "name": "David Rudolph"',
#   'email': ' "email": "david.rudolph@nelson.com"}'},
#  {'contact_id': '{"contact_id": 4995',
#   'name': ' "name": "Bryan Ross"',
#   'email': ' "email": "bryan.ross@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 3631',
#   'name': ' "name": "Ubaldo Brown"',
#   'email': ' "email": "ubaldo.brown@philippe.com"}'},
#  {'contact_id': '{"contact_id": 5373',
#   'name': ' "name": "Clelia Faulkner"',
#   'email': ' "email": "clelia.faulkner@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 3126',
#   'name': ' "name": "Sara Erickson"',
#   'email': ' "email": "sara.erickson@yahoo.de"}'},
#  {'contact_id': '{"contact_id": 2194',
#   'name': ' "name": "Rupert Valle"',
#   'email': ' "email": "rupert.valle@filogamo.it"}'},
#  {'contact_id': '{"contact_id": 2906',
#   'name': ' "name": "Puccio Kitzmann"',
#   'email': ' "email": "puccio.kitzmann@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 2611',
#   'name': ' "name": "Thomas Hutchinson"',
#   'email': ' "email": "thomas.hutchinson@gmx.de"}'},
#  {'contact_id': '{"contact_id": 2374',
#   'name': ' "name": "Abelardo Castro"',
#   'email': ' "email": "abelardo.castro@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3254',
#   'name': ' "name": "Greco Walker"',
#   'email': ' "email": "greco.walker@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 3571',
#   'name': ' "name": "Miranda Lacombe"',
#   'email': ' "email": "miranda.lacombe@longoria-vanegas.net"}'},
#  {'contact_id': '{"contact_id": 2812',
#   'name': ' "name": "Diana Schuchhardt"',
#   'email': ' "email": "diana.schuchhardt@libero.it"}'},
#  {'contact_id': '{"contact_id": 3961',
#   'name': ' "name": "Stacey Knox"',
#   'email': ' "email": "stacey.knox@corporacin.com"}'},
#  {'contact_id': '{"contact_id": 3872',
#   'name': ' "name": "Glen Faivre"',
#   'email': ' "email": "glen.faivre@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 4736',
#   'name': ' "name": "Andrew Torres"',
#   'email': ' "email": "andrew.torres@ruiz-torres.org"}'},
#  {'contact_id': '{"contact_id": 5119',
#   'name': ' "name": "Denny Fritz"',
#   'email': ' "email": "denny.fritz@despacho.biz"}'},
#  {'contact_id': '{"contact_id": 5725',
#   'name': ' "name": "Martyn Caldera"',
#   'email': ' "email": "martyn.caldera@hotmail.co.uk"}'},
#  {'contact_id': '{"contact_id": 4037',
#   'name': ' "name": "Abigail Foster"',
#   'email': ' "email": "abigail.foster@taylor.net"}'},
#  {'contact_id': '{"contact_id": 2109',
#   'name': ' "name": "Anthony Hauffer"',
#   'email': ' "email": "anthony.hauffer@tlustek.org"}'},
#  {'contact_id': '{"contact_id": 3283',
#   'name': ' "name": "Roger Gerlach"',
#   'email': ' "email": "roger.gerlach@may-mitchell.co.uk"}'},
#  {'contact_id': '{"contact_id": 6181',
#   'name': ' "name": "Christopher Poirier"',
#   'email': ' "email": "christopher.poirier@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 3251',
#   'name': ' "name": "Branka Traore"',
#   'email': ' "email": "branka.traore@jacobi.com"}'},
#  {'contact_id': '{"contact_id": 3443',
#   'name': ' "name": "Briana Etienne"',
#   'email': ' "email": "briana.etienne@bishop-coates.com"}'},
#  {'contact_id': '{"contact_id": 2988',
#   'name': ' "name": "Brandon Olson"',
#   'email': ' "email": "brandon.olson@prince-moreno.net"}'},
#  {'contact_id': '{"contact_id": 1673',
#   'name': ' "name": "Celia Ungaretti"',
#   'email': ' "email": "celia.ungaretti@fox.com"}'},
#  {'contact_id': '{"contact_id": 2085',
#   'name': ' "name": "Barbara Guibert"',
#   'email': ' "email": "barbara.guibert@casares-sanches.com"}'},
#  {'contact_id': '{"contact_id": 1672',
#   'name': ' "name": "Daniela Bell"',
#   'email': ' "email": "daniela.bell@vollbrecht.org"}'},
#  {'contact_id': '{"contact_id": 4426',
#   'name': ' "name": "Phyllis Gurule"',
#   'email': ' "email": "phyllis.gurule@rodriguez-pham.com"}'},
#  {'contact_id': '{"contact_id": 3211',
#   'name': ' "name": "Alejandra Joseph"',
#   'email': ' "email": "alejandra.joseph@escalante-abrego.biz"}'},
#  {'contact_id': '{"contact_id": 3190',
#   'name': ' "name": "Giulio Bohlander"',
#   'email': ' "email": "giulio.bohlander@dbmail.com"}'},
#  {'contact_id': '{"contact_id": 2081',
#   'name': ' "name": "Amber Weller"',
#   'email': ' "email": "amber.weller@toso.eu"}'},
#  {'contact_id': '{"contact_id": 3185',
#   'name': ' "name": "Mary Etzold"',
#   'email': ' "email": "mary.etzold@conrad-harrison.com"}'},
#  {'contact_id': '{"contact_id": 5044',
#   'name': ' "name": "Amy Georges"',
#   'email': ' "email": "amy.georges@raedel.de"}'},
#  {'contact_id': '{"contact_id": 1883',
#   'name': ' "name": "Jennifer Giraud"',
#   'email': ' "email": "jennifer.giraud@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 2067',
#   'name': ' "name": "Rosie Peltier"',
#   'email': ' "email": "rosie.peltier@voila.fr"}'},
#  {'contact_id': '{"contact_id": 4604',
#   'name': ' "name": "Oreste Ward"',
#   'email': ' "email": "oreste.ward@proyectos.com"}'},
#  {'contact_id': '{"contact_id": 3203',
#   'name': ' "name": "Luis Edwards"',
#   'email': ' "email": "luis.edwards@live.com"}'},
#  {'contact_id': '{"contact_id": 5758',
#   'name': ' "name": "Fiona Griffiths"',
#   'email': ' "email": "fiona.griffiths@curatoli-verdone.it"}'},
#  {'contact_id': '{"contact_id": 5755',
#   'name': ' "name": "Sally Raya"',
#   'email': ' "email": "sally.raya@tarchetti.it"}'},
#  {'contact_id': '{"contact_id": 5150',
#   'name': ' "name": "Carolyn Charpentier"',
#   'email': ' "email": "carolyn.charpentier@hotmail.de"}'},
#  {'contact_id': '{"contact_id": 4181',
#   'name': ' "name": "Nathalie Alvarez"',
#   'email': ' "email": "nathalie.alvarez@live.com"}'},
#  {'contact_id': '{"contact_id": 3006',
#   'name': ' "name": "Abril Lowery"',
#   'email': ' "email": "abril.lowery@novak.net"}'},
#  {'contact_id': '{"contact_id": 4865',
#   'name': ' "name": "Ottone Sullivan"',
#   'email': ' "email": "ottone.sullivan@hussain-kaur.com"}'},
#  {'contact_id': '{"contact_id": 2862',
#   'name': ' "name": "Esmeralda Sollima"',
#   'email': ' "email": "esmeralda.sollima@visintini.it"}'},
#  {'contact_id': '{"contact_id": 6070',
#   'name': ' "name": "Silvia Gierschner"',
#   'email': ' "email": "silvia.gierschner@tele2.it"}'},
#  {'contact_id': '{"contact_id": 5300',
#   'name': ' "name": "Kyle Cunningham"',
#   'email': ' "email": "kyle.cunningham@voila.fr"}'},
#  {'contact_id': '{"contact_id": 3486',
#   'name': ' "name": "Anel Carpentier"',
#   'email': ' "email": "anel.carpentier@klein-joseph.org"}'},
#  {'contact_id': '{"contact_id": 5989',
#   'name': ' "name": "Sarah Davis"',
#   'email': ' "email": "sarah.davis@david.com"}'},
#  {'contact_id': '{"contact_id": 2849',
#   'name': ' "name": "Luke Klein"',
#   'email': ' "email": "luke.klein@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 1612',
#   'name': ' "name": "Gudrun Mueller"',
#   'email': ' "email": "gudrun.mueller@dillon-fuller.info"}'},
#  {'contact_id': '{"contact_id": 3307',
#   'name': ' "name": "Melissa Canali"',
#   'email': ' "email": "melissa.canali@libero.it"}'},
#  {'contact_id': '{"contact_id": 5288',
#   'name': ' "name": "Gabrielle Ayala"',
#   'email': ' "email": "gabrielle.ayala@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 6026',
#   'name': ' "name": "Laura Buckley"',
#   'email': ' "email": "laura.buckley@ryan.org"}'},
#  {'contact_id': '{"contact_id": 2212',
#   'name': ' "name": "Wilfrido Lorch"',
#   'email': ' "email": "wilfrido.lorch@leclerc.fr"}'},
#  {'contact_id': '{"contact_id": 4591',
#   'name': ' "name": "Robert Bruder"',
#   'email': ' "email": "robert.bruder@manzoni.com"}'},
#  {'contact_id': '{"contact_id": 2771',
#   'name': ' "name": "Phillip Soliz"',
#   'email': ' "email": "phillip.soliz@outlook.com"}'},
#  {'contact_id': '{"contact_id": 5682',
#   'name': ' "name": "Alex Smith"',
#   'email': ' "email": "alex.smith@fournier.fr"}'},
#  {'contact_id': '{"contact_id": 5368',
#   'name': ' "name": "Jessica Martinez"',
#   'email': ' "email": "jessica.martinez@salieri.com"}'},
#  {'contact_id': '{"contact_id": 3706',
#   'name': ' "name": "Kelly Carter"',
#   'email': ' "email": "kelly.carter@hotmail.com.au"}'},
#  {'contact_id': '{"contact_id": 4034',
#   'name': ' "name": "Ahmad Sosa"',
#   'email': ' "email": "ahmad.sosa@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3209',
#   'name': ' "name": "Toralf Iglesias"',
#   'email': ' "email": "toralf.iglesias@borrego.com"}'},
#  {'contact_id': '{"contact_id": 2384',
#   'name': ' "name": "Irene Anichini"',
#   'email': ' "email": "irene.anichini@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 3074',
#   'name': ' "name": "Alicia Cainero"',
#   'email': ' "email": "alicia.cainero@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 2031',
#   'name': ' "name": "Tracey Laboy"',
#   'email': ' "email": "tracey.laboy@bell.biz"}'},
#  {'contact_id': '{"contact_id": 5873',
#   'name': ' "name": "Donald Reynaud"',
#   'email': ' "email": "donald.reynaud@green.edu.au"}'},
#  {'contact_id': '{"contact_id": 5501',
#   'name': ' "name": "Venancio Stadelmann"',
#   'email': ' "email": "venancio.stadelmann@gmx.de"}'},
#  {'contact_id': '{"contact_id": 3489',
#   'name': ' "name": "Seth Olivier"',
#   'email': ' "email": "seth.olivier@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 4210',
#   'name': ' "name": "Dennis Boaga"',
#   'email': ' "email": "dennis.boaga@gmx.de"}'},
#  {'contact_id': '{"contact_id": 6151',
#   'name': ' "name": "Pedro Wilson"',
#   'email': ' "email": "pedro.wilson@outlook.com"}'},
#  {'contact_id': '{"contact_id": 6047',
#   'name': ' "name": "Roland Weihmann"',
#   'email': ' "email": "roland.weihmann@gmail.com"}'},
#  {'contact_id': '{"contact_id": 5445',
#   'name': ' "name": "Hector Morrison"',
#   'email': ' "email": "hector.morrison@web.de"}'},
#  {'contact_id': '{"contact_id": 5493',
#   'name': ' "name": "Evangelos Peters"',
#   'email': ' "email": "evangelos.peters@sanchez.net"}'},
#  {'contact_id': '{"contact_id": 6036',
#   'name': ' "name": "Gerardo Hamilton"',
#   'email': ' "email": "gerardo.hamilton@libero.it"}'},
#  {'contact_id': '{"contact_id": 2368',
#   'name': ' "name": "Meta Cuzzocrea"',
#   'email': ' "email": "meta.cuzzocrea@howard-jensen.org"}'},
#  {'contact_id': '{"contact_id": 1501',
#   'name': ' "name": "Alma Raymond"',
#   'email': ' "email": "alma.raymond@tin.it"}'},
#  {'contact_id': '{"contact_id": 4351',
#   'name': ' "name": "Kathleen Solimena"',
#   'email': ' "email": "kathleen.solimena@wallace.biz"}'},
#  {'contact_id': '{"contact_id": 3096',
#   'name': ' "name": "Zacharie Cordier"',
#   'email': ' "email": "zacharie.cordier@gmail.com"}'},
#  {'contact_id': '{"contact_id": 6162',
#   'name': ' "name": "Riza Techer"',
#   'email': ' "email": "riza.techer@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 1433',
#   'name': ' "name": "Enrique Guillen"',
#   'email': ' "email": "enrique.guillen@hotmail.co.uk"}'},
#  {'contact_id': '{"contact_id": 2720',
#   'name': ' "name": "Tristan Weeks"',
#   'email': ' "email": "tristan.weeks@pena.com"}'},
#  {'contact_id': '{"contact_id": 5251',
#   'name': ' "name": "Natalie Lerma"',
#   'email': ' "email": "natalie.lerma@boucher.com"}'},
#  {'contact_id': '{"contact_id": 1797',
#   'name': ' "name": "Rodney Hamon"',
#   'email': ' "email": "rodney.hamon@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 1656',
#   'name': ' "name": "Adalberto Lombardo"',
#   'email': ' "email": "adalberto.lombardo@sfr.fr"}'},
#  {'contact_id': '{"contact_id": 1346',
#   'name': ' "name": "Florencia Querini"',
#   'email': ' "email": "florencia.querini@gmail.com"}'},
#  {'contact_id': '{"contact_id": 2989',
#   'name': ' "name": "Liam Rolland"',
#   'email': ' "email": "liam.rolland@yahoo.fr"}'},
#  {'contact_id': '{"contact_id": 5629',
#   'name': ' "name": "Ian Kelly"',
#   'email': ' "email": "ian.kelly@reeves.com.au"}'},
#  {'contact_id': '{"contact_id": 3456',
#   'name': ' "name": "Mehdi Todd"',
#   'email': ' "email": "mehdi.todd@web.de"}'},
#  {'contact_id': '{"contact_id": 3229',
#   'name': ' "name": "Rembrandt Liguori"',
#   'email': ' "email": "rembrandt.liguori@davis.org"}'},
#  {'contact_id': '{"contact_id": 2277',
#   'name': ' "name": "Irmi Schweitzer"',
#   'email': ' "email": "irmi.schweitzer@ozuna.com"}'},
#  {'contact_id': '{"contact_id": 1276',
#   'name': ' "name": "Gioffre Stein"',
#   'email': ' "email": "gioffre.stein@hotmail.com.au"}'},
#  {'contact_id': '{"contact_id": 3694',
#   'name': ' "name": "Frida Villarreal"',
#   'email': ' "email": "frida.villarreal@hotmail.de"}'},
#  {'contact_id': '{"contact_id": 2260',
#   'name': ' "name": "Steffen Mangold"',
#   'email': ' "email": "steffen.mangold@paul.net"}'},
#  {'contact_id': '{"contact_id": 5374',
#   'name': ' "name": "Elias Marin"',
#   'email': ' "email": "elias.marin@herve.net"}'},
#  {'contact_id': '{"contact_id": 4420',
#   'name': ' "name": "Roman Gonzalez"',
#   'email': ' "email": "roman.gonzalez@anderson.net"}'},
#  {'contact_id': '{"contact_id": 3849',
#   'name': ' "name": "Reina Middleton"',
#   'email': ' "email": "reina.middleton@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 1638',
#   'name': ' "name": "Sandro Moran"',
#   'email': ' "email": "sandro.moran@hotmail.de"}'},
#  {'contact_id': '{"contact_id": 5230',
#   'name': ' "name": "Gebhard Thanel"',
#   'email': ' "email": "gebhard.thanel@gmail.com"}'},
#  {'contact_id': '{"contact_id": 1763',
#   'name': ' "name": "Antonino Bolander"',
#   'email': ' "email": "antonino.bolander@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4323',
#   'name': ' "name": "Karl Trevisani"',
#   'email': ' "email": "karl.trevisani@anguissola.it"}'},
#  {'contact_id': '{"contact_id": 5256',
#   'name': ' "name": "Silvester Brookes"',
#   'email': ' "email": "silvester.brookes@franco.org"}'},
#  {'contact_id': '{"contact_id": 4836',
#   'name': ' "name": "Octavio Pratt"',
#   'email': ' "email": "octavio.pratt@web.de"}'},
#  {'contact_id': '{"contact_id": 5981',
#   'name': ' "name": "Rebecca Greer"',
#   'email': ' "email": "rebecca.greer@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 1463',
#   'name': ' "name": "Pierina Gaggini"',
#   'email': ' "email": "pierina.gaggini@free.fr"}'},
#  {'contact_id': '{"contact_id": 4577',
#   'name': ' "name": "Robin Schleich"',
#   'email': ' "email": "robin.schleich@rogers-barrera.biz"}'},
#  {'contact_id': '{"contact_id": 4951',
#   'name': ' "name": "Sergio Abbott"',
#   'email': ' "email": "sergio.abbott@moore.net.au"}'},
#  {'contact_id': '{"contact_id": 3567',
#   'name': ' "name": "Gilberto Evans"',
#   'email': ' "email": "gilberto.evans@salcedo-archuleta.net"}'},
#  {'contact_id': '{"contact_id": 5475',
#   'name': ' "name": "James Elliott"',
#   'email': ' "email": "james.elliott@gmail.com"}'},
#  {'contact_id': '{"contact_id": 2114',
#   'name': ' "name": "Timoteo Bolnbach"',
#   'email': ' "email": "timoteo.bolnbach@laboratorios.com"}'},
#  {'contact_id': '{"contact_id": 5216',
#   'name': ' "name": "Tonino Stanley"',
#   'email': ' "email": "tonino.stanley@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 1665',
#   'name': ' "name": "Margaretha Murialdo"',
#   'email': ' "email": "margaretha.murialdo@meunier.com"}'},
#  {'contact_id': '{"contact_id": 6051',
#   'name': ' "name": "Bianca Drubin"',
#   'email': ' "email": "bianca.drubin@libero.it"}'},
#  {'contact_id': '{"contact_id": 3983',
#   'name': ' "name": "Kaylee Hoffmann"',
#   'email': ' "email": "kaylee.hoffmann@poulain.com"}'},
#  {'contact_id': '{"contact_id": 2966',
#   'name': ' "name": "Teresa Vecellio"',
#   'email': ' "email": "teresa.vecellio@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 4478',
#   'name': ' "name": "Emine Tacchini"',
#   'email': ' "email": "emine.tacchini@dbmail.com"}'},
#  {'contact_id': '{"contact_id": 4238',
#   'name': ' "name": "Dawn Cortez"',
#   'email': ' "email": "dawn.cortez@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4404',
#   'name': ' "name": "Emily Cundari"',
#   'email': ' "email": "emily.cundari@clark.com.au"}'},
#  {'contact_id': '{"contact_id": 5666',
#   'name': ' "name": "Eleanor Hall"',
#   'email': ' "email": "eleanor.hall@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 3691',
#   'name': ' "name": "Monique Delgadillo"',
#   'email': ' "email": "monique.delgadillo@hotmail.co.uk"}'},
#  {'contact_id': '{"contact_id": 2703',
#   'name': ' "name": "Arnaude Warner"',
#   'email': ' "email": "arnaude.warner@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4253',
#   'name': ' "name": "Jason Howell"',
#   'email': ' "email": "jason.howell@gmx.de"}'},
#  {'contact_id': '{"contact_id": 5652',
#   'name': ' "name": "Nicole Mccullough"',
#   'email': ' "email": "nicole.mccullough@hall.com"}'},
#  {'contact_id': '{"contact_id": 3279',
#   'name': ' "name": "Rosmarie Esquibel"',
#   'email': ' "email": "rosmarie.esquibel@bouygtel.fr"}'},
#  {'contact_id': '{"contact_id": 3233',
#   'name': ' "name": "Leonor Ferreira"',
#   'email': ' "email": "leonor.ferreira@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3017',
#   'name': ' "name": "Brett Jones"',
#   'email': ' "email": "brett.jones@alice.it"}'},
#  {'contact_id': '{"contact_id": 3482',
#   'name': ' "name": "Nino Bien"',
#   'email': ' "email": "nino.bien@gmail.com"}'},
#  {'contact_id': '{"contact_id": 2166',
#   'name': ' "name": "Jemma Tate"',
#   'email': ' "email": "jemma.tate@hotmail.de"}'},
#  {'contact_id': '{"contact_id": 4146',
#   'name': ' "name": "Denis Rogers"',
#   'email': ' "email": "denis.rogers@poste.it"}'},
#  {'contact_id': '{"contact_id": 2651',
#   'name': ' "name": "Vanesa Khan"',
#   'email': ' "email": "vanesa.khan@voila.fr"}'},
#  {'contact_id': '{"contact_id": 1409',
#   'name': ' "name": "Victoria Ojeda"',
#   'email': ' "email": "victoria.ojeda@doehn.com"}'},
#  {'contact_id': '{"contact_id": 3717',
#   'name': ' "name": "Eugenio Martin"',
#   'email': ' "email": "eugenio.martin@yahoo.de"}'},
#  {'contact_id': '{"contact_id": 3963',
#   'name': ' "name": "Nancy Hayes"',
#   'email': ' "email": "nancy.hayes@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 2152',
#   'name': ' "name": "Lara Jacob"',
#   'email': ' "email": "lara.jacob@buckley.org"}'},
#  {'contact_id': '{"contact_id": 2974',
#   'name': ' "name": "Gino Hernandez"',
#   'email': ' "email": "gino.hernandez@covarrubias.com"}'},
#  {'contact_id': '{"contact_id": 1268',
#   'name': ' "name": "Vicente Tijerina"',
#   'email': ' "email": "vicente.tijerina@montanariello.com"}'},
#  {'contact_id': '{"contact_id": 1822',
#   'name': ' "name": "Michele Brambilla"',
#   'email': ' "email": "michele.brambilla@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 5066',
#   'name': ' "name": "Dana Ritacca"',
#   'email': ' "email": "dana.ritacca@gmail.com"}'},
#  {'contact_id': '{"contact_id": 5075',
#   'name': ' "name": "Mitchell Bachmann"',
#   'email': ' "email": "mitchell.bachmann@suarez-cruz.com"}'},
#  {'contact_id': '{"contact_id": 3855',
#   'name': ' "name": "Vincenza Key"',
#   'email': ' "email": "vincenza.key@adams.com"}'},
#  {'contact_id': '{"contact_id": 5923',
#   'name': ' "name": "Salvador Gaillard"',
#   'email': ' "email": "salvador.gaillard@yahoo.de"}'},
#  {'contact_id': '{"contact_id": 1867',
#   'name': ' "name": "Diane Rogner"',
#   'email': ' "email": "diane.rogner@kelly.co.uk"}'},
#  {'contact_id': '{"contact_id": 4376',
#   'name': ' "name": "Josette Laine"',
#   'email': ' "email": "josette.laine@saracino-parisi.net"}'},
#  {'contact_id': '{"contact_id": 2785',
#   'name': ' "name": "Courtney Fiebig"',
#   'email': ' "email": "courtney.fiebig@doerschner.com"}'},
#  {'contact_id': '{"contact_id": 5884',
#   'name': ' "name": "Hugues Oliver"',
#   'email': ' "email": "hugues.oliver@stiffel.com"}'},
#  {'contact_id': '{"contact_id": 2441',
#   'name': ' "name": "Espartaco Willis"',
#   'email': ' "email": "espartaco.willis@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 1243',
#   'name': ' "name": "Flavia Yoder"',
#   'email': ' "email": "flavia.yoder@hotmail.de"}'},
#  {'contact_id': '{"contact_id": 3411',
#   'name': ' "name": "Casey Flores"',
#   'email': ' "email": "casey.flores@baggio.org"}'},
#  {'contact_id': '{"contact_id": 2467',
#   'name': ' "name": "Calogero Cross"',
#   'email': ' "email": "calogero.cross@mercantini.it"}'},
#  {'contact_id': '{"contact_id": 1850',
#   'name': ' "name": "Charles Begum"',
#   'email': ' "email": "charles.begum@laboratorios.info"}'},
#  {'contact_id': '{"contact_id": 2604',
#   'name': ' "name": "Adina Pollard"',
#   'email': ' "email": "adina.pollard@outlook.com"}'},
#  {'contact_id': '{"contact_id": 1693',
#   'name': ' "name": "Natasha Lara"',
#   'email': ' "email": "natasha.lara@outlook.com"}'},
#  {'contact_id': '{"contact_id": 2969',
#   'name': ' "name": "Benita Pottier"',
#   'email': ' "email": "benita.pottier@sfr.fr"}'},
#  {'contact_id': '{"contact_id": 1544',
#   'name': ' "name": "Elizabeth Valdivia"',
#   'email': ' "email": "elizabeth.valdivia@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4149',
#   'name': ' "name": "Mattia Huet"',
#   'email': ' "email": "mattia.huet@aol.de"}'},
#  {'contact_id': '{"contact_id": 3463',
#   'name': ' "name": "Geza Howard"',
#   'email': ' "email": "geza.howard@voila.fr"}'},
#  {'contact_id': '{"contact_id": 2939',
#   'name': ' "name": "Lauren Guillaume"',
#   'email': ' "email": "lauren.guillaume@sorgatz.org"}'},
#  {'contact_id': '{"contact_id": 2202',
#   'name': ' "name": "Joanna Baxter"',
#   'email': ' "email": "joanna.baxter@bruce-wright.com"}'},
#  {'contact_id': '{"contact_id": 1728',
#   'name': ' "name": "Tracy Metz"',
#   'email': ' "email": "tracy.metz@bryant.info"}'},
#  {'contact_id': '{"contact_id": 5362',
#   'name': ' "name": "Birgit Pena"',
#   'email': ' "email": "birgit.pena@armellini.it"}'},
#  {'contact_id': '{"contact_id": 4840',
#   'name': ' "name": "Elvira Papafava"',
#   'email': ' "email": "elvira.papafava@ifrance.com"}'},
#  {'contact_id': '{"contact_id": 2955',
#   'name': ' "name": "Ernest Delorme"',
#   'email': ' "email": "ernest.delorme@dowerg.de"}'},
#  {'contact_id': '{"contact_id": 5354',
#   'name': ' "name": "Christy Grossi"',
#   'email': ' "email": "christy.grossi@alarcon-tafoya.com"}'},
#  {'contact_id': '{"contact_id": 3847',
#   'name': ' "name": "Hermelinda Olmos"',
#   'email': ' "email": "hermelinda.olmos@portillo.com"}'},
#  {'contact_id': '{"contact_id": 3025',
#   'name': ' "name": "Herbert Fraser"',
#   'email': ' "email": "herbert.fraser@holloway.org.au"}'},
#  {'contact_id': '{"contact_id": 1615',
#   'name': ' "name": "Giancarlo Heydrich"',
#   'email': ' "email": "giancarlo.heydrich@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 5154',
#   'name': ' "name": "Constance Maldonado"',
#   'email': ' "email": "constance.maldonado@spiess.net"}'},
#  {'contact_id': '{"contact_id": 5005',
#   'name': ' "name": "Giampiero Carlier"',
#   'email': ' "email": "giampiero.carlier@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 1349',
#   'name': ' "name": "Carlo Jacquot"',
#   'email': ' "email": "carlo.jacquot@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 3670',
#   'name': ' "name": "Gabriel Robles"',
#   'email': ' "email": "gabriel.robles@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 2912',
#   'name': ' "name": "Gerd Gunpf"',
#   'email': ' "email": "gerd.gunpf@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4336',
#   'name': ' "name": "Ashley Hellwig"',
#   'email': ' "email": "ashley.hellwig@libero.it"}'},
#  {'contact_id': '{"contact_id": 5576',
#   'name': ' "name": "Patrick Rosas"',
#   'email': ' "email": "patrick.rosas@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 2736',
#   'name': ' "name": "Lilla Leonard"',
#   'email': ' "email": "lilla.leonard@jungfer.com"}'},
#  {'contact_id': '{"contact_id": 3321',
#   'name': ' "name": "Tony Nicolas"',
#   'email': ' "email": "tony.nicolas@morrocco-seddio.net"}'},
#  {'contact_id': '{"contact_id": 3353',
#   'name': ' "name": "Allegra Benedetti"',
#   'email': ' "email": "allegra.benedetti@miller.com"}'},
#  {'contact_id': '{"contact_id": 2336',
#   'name': ' "name": "Camille Tafuri"',
#   'email': ' "email": "camille.tafuri@aol.de"}'},
#  {'contact_id': '{"contact_id": 4369',
#   'name': ' "name": "Juan Wheeler"',
#   'email': ' "email": "juan.wheeler@gilmore.net"}'},
#  {'contact_id': '{"contact_id": 4464',
#   'name': ' "name": "Leopoldo Johnson"',
#   'email': ' "email": "leopoldo.johnson@hotmail.com.au"}'},
#  {'contact_id': '{"contact_id": 5626',
#   'name': ' "name": "Dietmar Grenier"',
#   'email': ' "email": "dietmar.grenier@tele2.it"}'},
#  {'contact_id': '{"contact_id": 1669',
#   'name': ' "name": "Leonid Scholl"',
#   'email': ' "email": "leonid.scholl@collin.com"}'},
#  {'contact_id': '{"contact_id": 5544',
#   'name': ' "name": "Olivie Contarini"',
#   'email': ' "email": "olivie.contarini@marshall-wright.biz"}'},
#  {'contact_id': '{"contact_id": 6078',
#   'name': ' "name": "Jeffery Lacroix"',
#   'email': ' "email": "jeffery.lacroix@medina.org"}'},
#  {'contact_id': '{"contact_id": 2580',
#   'name': ' "name": "Edeltraud Chavez"',
#   'email': ' "email": "edeltraud.chavez@hotmail.com.au"}'},
#  {'contact_id': '{"contact_id": 3592',
#   'name': ' "name": "Mesut Morvan"',
#   'email': ' "email": "mesut.morvan@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4914',
#   'name': ' "name": "Gregory Jackson"',
#   'email': ' "email": "gregory.jackson@ortiz.com"}'},
#  {'contact_id': '{"contact_id": 3848',
#   'name': ' "name": "Nicola Rossi"',
#   'email': ' "email": "nicola.rossi@berry.org"}'},
#  {'contact_id': '{"contact_id": 2619',
#   'name': ' "name": "Eddie Collazo"',
#   'email': ' "email": "eddie.collazo@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4605',
#   'name': ' "name": "Philippe Gardner"',
#   'email': ' "email": "philippe.gardner@howells-jones.net"}'},
#  {'contact_id': '{"contact_id": 6147',
#   'name': ' "name": "Roy Fox"',
#   'email': ' "email": "roy.fox@tejeda.com"}'},
#  {'contact_id': '{"contact_id": 1383',
#   'name': ' "name": "Heiderose Garcia"',
#   'email': ' "email": "heiderose.garcia@noos.fr"}'},
#  {'contact_id': '{"contact_id": 1757',
#   'name': ' "name": "Claudine Rowley"',
#   'email': ' "email": "claudine.rowley@industrias.com"}'},
#  {'contact_id': '{"contact_id": 4390',
#   'name': ' "name": "Astrid Roht"',
#   'email': ' "email": "astrid.roht@fastwebnet.it"}'},
#  {'contact_id': '{"contact_id": 4165',
#   'name': ' "name": "Auguste Burnett"',
#   'email': ' "email": "auguste.burnett@yahoo.fr"}'},
#  {'contact_id': '{"contact_id": 4529',
#   'name': ' "name": "Pellegrino Allen"',
#   'email': ' "email": "pellegrino.allen@gmail.com"}'},
#  {'contact_id': '{"contact_id": 6084',
#   'name': ' "name": "Angela Bowers"',
#   'email': ' "email": "angela.bowers@laboratorios.com"}'},
#  {'contact_id': '{"contact_id": 2916',
#   'name': ' "name": "Michael Descamps"',
#   'email': ' "email": "michael.descamps@gmail.com"}'},
#  {'contact_id': '{"contact_id": 2005',
#   'name': ' "name": "Heidelore Kennedy"',
#   'email': ' "email": "heidelore.kennedy@guinizzelli.org"}'},
#  {'contact_id': '{"contact_id": 2261',
#   'name': ' "name": "Lucrezia Koch"',
#   'email': ' "email": "lucrezia.koch@petit.com"}'},
#  {'contact_id': '{"contact_id": 5342',
#   'name': ' "name": "Ivan Accardo"',
#   'email': ' "email": "ivan.accardo@web.de"}'},
#  {'contact_id': '{"contact_id": 4087',
#   'name': ' "name": "Karen Avogadro"',
#   'email': ' "email": "karen.avogadro@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 2761',
#   'name': ' "name": "Laetitia Gallet"',
#   'email': ' "email": "laetitia.gallet@aubry.org"}'},
#  {'contact_id': '{"contact_id": 2908',
#   'name': ' "name": "Amico Gosselin"',
#   'email': ' "email": "amico.gosselin@shaw.info"}'},
#  {'contact_id': '{"contact_id": 2155',
#   'name': ' "name": "Ilaria Bowen"',
#   'email': ' "email": "ilaria.bowen@hotmail.it"}'},
#  {'contact_id': '{"contact_id": 5642',
#   'name': ' "name": "Marlen Coardi"',
#   'email': ' "email": "marlen.coardi@colletti.eu"}'},
#  {'contact_id': '{"contact_id": 6217',
#   'name': ' "name": "Rafael Alexander"',
#   'email': ' "email": "rafael.alexander@jenkins.com"}'},
#  {'contact_id': '{"contact_id": 4222',
#   'name': ' "name": "Herma Gabbana"',
#   'email': ' "email": "herma.gabbana@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 4798',
#   'name': ' "name": "Zachary Vespucci"',
#   'email': ' "email": "zachary.vespucci@industrias.com"}'},
#  {'contact_id': '{"contact_id": 5660',
#   'name': ' "name": "Marisol Richard"',
#   'email': ' "email": "marisol.richard@gmail.com"}'},
#  {'contact_id': '{"contact_id": 5000',
#   'name': ' "name": "Joseph Glover"',
#   'email': ' "email": "joseph.glover@laposte.net"}'},
#  {'contact_id': '{"contact_id": 2809',
#   'name': ' "name": "Lauretta Neal"',
#   'email': ' "email": "lauretta.neal@hotmail.de"}'},
#  {'contact_id': '{"contact_id": 3349',
#   'name': ' "name": "Simone Sauvage"',
#   'email': ' "email": "simone.sauvage@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 3647',
#   'name': ' "name": "Ramona Brooks"',
#   'email': ' "email": "ramona.brooks@kensy.de"}'},
#  {'contact_id': '{"contact_id": 5745',
#   'name': ' "name": "Gioele Schwital"',
#   'email': ' "email": "gioele.schwital@moody.com"}'},
#  {'contact_id': '{"contact_id": 2583',
#   'name': ' "name": "Elena Jimenez"',
#   'email': ' "email": "elena.jimenez@yahoo.com.au"}'},
#  {'contact_id': '{"contact_id": 5441',
#   'name': ' "name": "Pam Vargas"',
#   'email': ' "email": "pam.vargas@guillot.net"}'},
#  {'contact_id': '{"contact_id": 2090',
#   'name': ' "name": "Alison Morales"',
#   'email': ' "email": "alison.morales@lewis.com"}'},
#  {'contact_id': '{"contact_id": 3386',
#   'name': ' "name": "Marc Aumann"',
#   'email': ' "email": "marc.aumann@holland.com"}'},
#  {'contact_id': '{"contact_id": 1816',
#   'name': ' "name": "Carla Butler"',
#   'email': ' "email": "carla.butler@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 4718',
#   'name': ' "name": "Dionigi Bruce"',
#   'email': ' "email": "dionigi.bruce@industrias.com"}'},
#  {'contact_id': '{"contact_id": 1677',
#   'name': ' "name": "Frank Henry"',
#   'email': ' "email": "frank.henry@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 4218',
#   'name': ' "name": "Brent Pons"',
#   'email': ' "email": "brent.pons@proyectos.net"}'},
#  {'contact_id': '{"contact_id": 4548',
#   'name': ' "name": "Patricia Liebelt"',
#   'email': ' "email": "patricia.liebelt@baca.org"}'},
#  {'contact_id': '{"contact_id": 1431',
#   'name': ' "name": "Micheletto Sykes"',
#   'email': ' "email": "micheletto.sykes@thompson-thompson.com"}'},
#  {'contact_id': '{"contact_id": 2830',
#   'name': ' "name": "Rose Blanc"',
#   'email': ' "email": "rose.blanc@grupo.com"}'},
#  {'contact_id': '{"contact_id": 4400',
#   'name': ' "name": "Vincent Singh"',
#   'email': ' "email": "vincent.singh@gmail.com"}'},
#  {'contact_id': '{"contact_id": 5773',
#   'name': ' "name": "Jamie Peacock"',
#   'email': ' "email": "jamie.peacock@interiano-nordio.com"}'},
#  {'contact_id': '{"contact_id": 4161',
#   'name': ' "name": "Giorgia Dijoux"',
#   'email': ' "email": "giorgia.dijoux@paul.com"}'},
#  {'contact_id': '{"contact_id": 2062',
#   'name': ' "name": "Serena Piacentini"',
#   'email': ' "email": "serena.piacentini@yahoo.de"}'},
#  {'contact_id': '{"contact_id": 3458',
#   'name': ' "name": "Dimitri Posada"',
#   'email': ' "email": "dimitri.posada@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3174',
#   'name': ' "name": "Alexa Barillaro"',
#   'email': ' "email": "alexa.barillaro@ramos.net"}'},
#  {'contact_id': '{"contact_id": 5565',
#   'name': ' "name": "Megan Kuhl"',
#   'email': ' "email": "megan.kuhl@despacho.com"}'},
#  {'contact_id': '{"contact_id": 1906',
#   'name': ' "name": "Kaitlyn Farinelli"',
#   'email': ' "email": "kaitlyn.farinelli@outlook.com"}'},
#  {'contact_id': '{"contact_id": 5479',
#   'name': ' "name": "Jonathan Castellitto"',
#   'email': ' "email": "jonathan.castellitto@libero.it"}'},
#  {'contact_id': '{"contact_id": 4320',
#   'name': ' "name": "Lisa Terragni"',
#   'email': ' "email": "lisa.terragni@proyectos.com"}'},
#  {'contact_id': '{"contact_id": 4213',
#   'name': ' "name": "Olivier Petrucelli"',
#   'email': ' "email": "olivier.petrucelli@letta-raurica.eu"}'},
#  {'contact_id': '{"contact_id": 3373',
#   'name': ' "name": "Jos Trobbiani"',
#   'email': ' "email": "jos.trobbiani@samson.com"}'},
#  {'contact_id': '{"contact_id": 4184',
#   'name': ' "name": "Mirjam Dawson"',
#   'email': ' "email": "mirjam.dawson@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 5472',
#   'name': ' "name": "Javier Tessier"',
#   'email': ' "email": "javier.tessier@mclaughlin.biz"}'},
#  {'contact_id': '{"contact_id": 5559',
#   'name': ' "name": "Mirjana Collins"',
#   'email': ' "email": "mirjana.collins@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 5419',
#   'name': ' "name": "Vanessa Tschentscher"',
#   'email': ' "email": "vanessa.tschentscher@mitchell.com"}'},
#  {'contact_id': '{"contact_id": 4171',
#   'name': ' "name": "Antonina Cobb"',
#   'email': ' "email": "antonina.cobb@gibson.org"}'},
#  {'contact_id': '{"contact_id": 1302',
#   'name': ' "name": "Bernard Durand"',
#   'email': ' "email": "bernard.durand@royer.com"}'},
#  {'contact_id': '{"contact_id": 3520',
#   'name': ' "name": "Corey Greggio"',
#   'email': ' "email": "corey.greggio@johnson.org.au"}'},
#  {'contact_id': '{"contact_id": 6010',
#   'name': ' "name": "Rodolfo Couturier"',
#   'email': ' "email": "rodolfo.couturier@tim.it"}'},
#  {'contact_id': '{"contact_id": 4617',
#   'name': ' "name": "Pierre Cardenas"',
#   'email': ' "email": "pierre.cardenas@luzi-bonomo.eu"}'},
#  {'contact_id': '{"contact_id": 1417',
#   'name': ' "name": "Romeo Surian"',
#   'email': ' "email": "romeo.surian@batista.com"}'},
#  {'contact_id': '{"contact_id": 4770',
#   'name': ' "name": "Ivo Moreno"',
#   'email': ' "email": "ivo.moreno@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 4328',
#   'name': ' "name": "Federico Marie"',
#   'email': ' "email": "federico.marie@jourdan.fr"}'},
#  {'contact_id': '{"contact_id": 5171',
#   'name': ' "name": "Maggie Boito"',
#   'email': ' "email": "maggie.boito@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 4394',
#   'name': ' "name": "Brianna Hanson"',
#   'email': ' "email": "brianna.hanson@stanley.com"}'},
#  {'contact_id': '{"contact_id": 1794',
#   'name': ' "name": "Heiko Bourgeois"',
#   'email': ' "email": "heiko.bourgeois@togliatti.com"}'},
#  {'contact_id': '{"contact_id": 3510',
#   'name': ' "name": "Benito Gritti"',
#   'email': ' "email": "benito.gritti@gmail.com"}'},
#  {'contact_id': '{"contact_id": 2487',
#   'name': ' "name": "Mitzy Junk"',
#   'email': ' "email": "mitzy.junk@zaragoza.com"}'},
#  {'contact_id': '{"contact_id": 2215',
#   'name': ' "name": "Samantha Lowe"',
#   'email': ' "email": "samantha.lowe@praga.it"}'},
#  {'contact_id': '{"contact_id": 4136',
#   'name': ' "name": "Ernesto Nerger"',
#   'email': ' "email": "ernesto.nerger@middleton.co.uk"}'},
#  {'contact_id': '{"contact_id": 3723',
#   'name': ' "name": "Melinda Canova"',
#   'email': ' "email": "melinda.canova@orange.fr"}'},
#  {'contact_id': '{"contact_id": 5842',
#   'name': ' "name": "Mohammad Hartung"',
#   'email': ' "email": "mohammad.hartung@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 3289',
#   'name': ' "name": "Ben Maillot"',
#   'email': ' "email": "ben.maillot@ramos.net"}'},
#  {'contact_id': '{"contact_id": 1249',
#   'name': ' "name": "Isabel Pruschke"',
#   'email': ' "email": "isabel.pruschke@gmail.com"}'},
#  {'contact_id': '{"contact_id": 5409',
#   'name': ' "name": "Linda Franceschi"',
#   'email': ' "email": "linda.franceschi@richards.net"}'},
#  {'contact_id': '{"contact_id": 2951',
#   'name': ' "name": "Olivia Striebitz"',
#   'email': ' "email": "olivia.striebitz@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3432',
#   'name': ' "name": "Penny Watson"',
#   'email': ' "email": "penny.watson@matthews.net"}'},
#  {'contact_id': '{"contact_id": 2297',
#   'name': ' "name": "Manfred James"',
#   'email': ' "email": "manfred.james@davies.org"}'},
#  {'contact_id': '{"contact_id": 6161',
#   'name': ' "name": "Hazel Pierce"',
#   'email': ' "email": "hazel.pierce@outlook.com"}'},
#  {'contact_id': '{"contact_id": 4603',
#   'name': ' "name": "Alf Bates"',
#   'email': ' "email": "alf.bates@dunn.com"}'},
#  {'contact_id': '{"contact_id": 5818',
#   'name': ' "name": "Scott Gough"',
#   'email': ' "email": "scott.gough@industrias.com"}'},
#  {'contact_id': '{"contact_id": 4270',
#   'name': ' "name": "Konrad Briones"',
#   'email': ' "email": "konrad.briones@fierro.com"}'},
#  {'contact_id': '{"contact_id": 6007',
#   'name': ' "name": "Mathilde Kruschwitz"',
#   'email': ' "email": "mathilde.kruschwitz@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 4084',
#   'name': ' "name": "Irma Gemito"',
#   'email': ' "email": "irma.gemito@googlemail.com"}'},
#  {'contact_id': '{"contact_id": 1340',
#   'name': ' "name": "Antoine Guyon"',
#   'email': ' "email": "antoine.guyon@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 5675',
#   'name': ' "name": "William Gibilisco"',
#   'email': ' "email": "william.gibilisco@gaillard.com"}'},
#  {'contact_id': '{"contact_id": 2010',
#   'name': ' "name": "Judith Butte"',
#   'email': ' "email": "judith.butte@fischer-vaughn.info"}'},
#  {'contact_id': '{"contact_id": 6201',
#   'name': ' "name": "Joanne Henderson"',
#   'email': ' "email": "joanne.henderson@gmail.com"}'},
#  {'contact_id': '{"contact_id": 1791',
#   'name': ' "name": "Ludovica Arellano"',
#   'email': ' "email": "ludovica.arellano@morandi-argento.com"}'},
#  {'contact_id': '{"contact_id": 3314',
#   'name': ' "name": "Catherine Gray"',
#   'email': ' "email": "catherine.gray@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 5852',
#   'name': ' "name": "Franco Fioravanti"',
#   'email': ' "email": "franco.fioravanti@barry-gill.com.au"}'},
#  {'contact_id': '{"contact_id": 4618',
#   'name': ' "name": "Heather Zimmer"',
#   'email': ' "email": "heather.zimmer@bluemel.de"}'},
#  {'contact_id': '{"contact_id": 2618',
#   'name': ' "name": "Hortense Taylor"',
#   'email': ' "email": "hortense.taylor@chambers.biz"}'},
#  {'contact_id': '{"contact_id": 4967',
#   'name': ' "name": "Livia Ernst"',
#   'email': ' "email": "livia.ernst@colas.fr"}'},
#  {'contact_id': '{"contact_id": 4594',
#   'name': ' "name": "Toby Etzler"',
#   'email': ' "email": "toby.etzler@industrias.com"}'},
#  {'contact_id': '{"contact_id": 2080',
#   'name': ' "name": "Ennio Leoncavallo"',
#   'email': ' "email": "ennio.leoncavallo@sanchez.org"}'},
#  {'contact_id': '{"contact_id": 2793',
#   'name': ' "name": "Philippine Vaca"',
#   'email': ' "email": "philippine.vaca@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 4890',
#   'name': ' "name": "Rhonda Phillips"',
#   'email': ' "email": "rhonda.phillips@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 3528',
#   'name': ' "name": "Alphonse Nitto"',
#   'email': ' "email": "alphonse.nitto@voila.fr"}'},
#  {'contact_id': '{"contact_id": 5810',
#   'name': ' "name": "Karina Arreola"',
#   'email': ' "email": "karina.arreola@yahoo.com.au"}'},
#  {'contact_id': '{"contact_id": 5720',
#   'name': ' "name": "Denise Wood"',
#   'email': ' "email": "denise.wood@mantegna.com"}'},
#  {'contact_id': '{"contact_id": 4593',
#   'name': ' "name": "Burghard Rosenow"',
#   'email': ' "email": "burghard.rosenow@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 3186',
#   'name': ' "name": "Friedl Powell"',
#   'email': ' "email": "friedl.powell@laposte.net"}'},
#  {'contact_id': '{"contact_id": 5136',
#   'name': ' "name": "Benjamin Schultz"',
#   'email': ' "email": "benjamin.schultz@rivero-davila.com"}'},
#  {'contact_id': '{"contact_id": 2646',
#   'name': ' "name": "Rachel Ulibarri"',
#   'email': ' "email": "rachel.ulibarri@schueler.com"}'},
#  {'contact_id': '{"contact_id": 3460',
#   'name': ' "name": "Silvano Blanchet"',
#   'email': ' "email": "silvano.blanchet@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 4345',
#   'name': ' "name": "Kurt Sauer"',
#   'email': ' "email": "kurt.sauer@almanza.biz"}'},
#  {'contact_id': '{"contact_id": 2690',
#   'name': ' "name": "Nayeli Gehringer"',
#   'email': ' "email": "nayeli.gehringer@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 4025',
#   'name': ' "name": "Imelda Guerin"',
#   'email': ' "email": "imelda.guerin@stumpf.net"}'},
#  {'contact_id': '{"contact_id": 4524',
#   'name': ' "name": "Zbigniew Holmes"',
#   'email': ' "email": "zbigniew.holmes@stiffel.net"}'},
#  {'contact_id': '{"contact_id": 3978',
#   'name': ' "name": "Adela Alfonsi"',
#   'email': ' "email": "adela.alfonsi@despacho.com"}'},
#  {'contact_id': '{"contact_id": 3910',
#   'name': ' "name": "Hilary Clark"',
#   'email': ' "email": "hilary.clark@libero.it"}'},
#  {'contact_id': '{"contact_id": 5825',
#   'name': ' "name": "Kornelius Molina"',
#   'email': ' "email": "kornelius.molina@heuser.com"}'},
#  {'contact_id': '{"contact_id": 3564',
#   'name': ' "name": "Christian Anderson"',
#   'email': ' "email": "christian.anderson@tim.it"}'},
#  {'contact_id': '{"contact_id": 2396',
#   'name': ' "name": "Francisco Dorsey"',
#   'email': ' "email": "francisco.dorsey@tiscali.fr"}'},
#  {'contact_id': '{"contact_id": 2140',
#   'name': ' "name": "Walli Albert"',
# ...
#  {'contact_id': '{"contact_id": 5139',
#   'name': ' "name": "Grit Knight"',
#   'email': ' "email": "grit.knight@web.de"}'},
#  {'contact_id': '{"contact_id": 3173',
#   'name': ' "name": "Erin Weinhold"',
#   'email': ' "email": "erin.weinhold@hotmail.fr"}'},
#  {'contact_id': '{"contact_id": 3333',
#   'name': ' "name": "Craig Jordan"',
#   'email': ' "email": "craig.jordan@gmail.com"}'},
#  {'contact_id': '{"contact_id": 2262',
#   'name': ' "name": "Homero Respighi"',
#   'email': ' "email": "homero.respighi@gmail.com"}'},
#  {'contact_id': '{"contact_id": 1531',
#   'name': ' "name": "Fanny Pertile"',
#   'email': ' "email": "fanny.pertile@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4881',
#   'name': ' "name": "Fridolin Comboni"',
#   'email': ' "email": "fridolin.comboni@graf.com"}'},
#  {'contact_id': '{"contact_id": 3928',
#   'name': ' "name": "Hugh Cantu"',
#   'email': ' "email": "hugh.cantu@libero.it"}'},
#  {'contact_id': '{"contact_id": 1803',
#   'name': ' "name": "Alphons Simmons"',
#   'email': ' "email": "alphons.simmons@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 2321',
#   'name': ' "name": "Ludovico Cafarchia"',
#   'email': ' "email": "ludovico.cafarchia@gmail.com"}'},
#  {'contact_id': '{"contact_id": 6234',
#   'name': ' "name": "Nico Kaiser"',
#   'email': ' "email": "nico.kaiser@almonte.com"}'},
#  {'contact_id': '{"contact_id": 1422',
#   'name': ' "name": "Kirsty Lamy"',
#   'email': ' "email": "kirsty.lamy@alonzi.it"}'},
#  {'contact_id': '{"contact_id": 2660',
#   'name': ' "name": "Joshua Scheibe"',
#   'email': ' "email": "joshua.scheibe@turci.org"}'},
#  {'contact_id': '{"contact_id": 5361',
#   'name': ' "name": "Carin Pineau"',
#   'email': ' "email": "carin.pineau@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 3420',
#   'name': ' "name": "Ellie Galarza"',
#   'email': ' "email": "ellie.galarza@pareto-cattaneo.net"}'},
#  {'contact_id': '{"contact_id": 4337',
#   'name': ' "name": "Marion Lira"',
#   'email': ' "email": "marion.lira@ifrance.com"}'},
#  {'contact_id': '{"contact_id": 2338',
#   'name': ' "name": "Aurelia Angiolello"',
#   'email': ' "email": "aurelia.angiolello@lord.com"}'},
#  {'contact_id': '{"contact_id": 4140',
#   'name': ' "name": "Maura Ravaglioli"',
#   'email': ' "email": "maura.ravaglioli@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 2373',
#   'name': ' "name": "Brunhilde Fletcher"',
#   'email': ' "email": "brunhilde.fletcher@schomber.de"}'},
#  {'contact_id': '{"contact_id": 1344',
#   'name': ' "name": "Ottfried Marques"',
#   'email': ' "email": "ottfried.marques@tyler-watson.info"}'},
#  {'contact_id': '{"contact_id": 2141',
#   'name': ' "name": "Christelle Blasi"',
#   'email': ' "email": "christelle.blasi@morris-chan.com"}'},
#  {'contact_id': '{"contact_id": 3415',
#   'name': ' "name": "Augusto Vercelloni"',
#   'email': ' "email": "augusto.vercelloni@club-internet.fr"}'},
#  {'contact_id': '{"contact_id": 5696',
#   'name': ' "name": "Michela Pruvost"',
#   'email': ' "email": "michela.pruvost@holt.co.uk"}'},
#  {'contact_id': '{"contact_id": 1798',
#   'name': ' "name": "Guarino Escalante"',
#   'email': ' "email": "guarino.escalante@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 1657',
#   'name': ' "name": "Gabriela Padilla"',
#   'email': ' "email": "gabriela.padilla@pearson-russell.com"}'},
#  {'contact_id': '{"contact_id": 3651',
#   'name': ' "name": "Agathe Dias"',
#   'email': ' "email": "agathe.dias@jackson.com"}'},
#  {'contact_id': '{"contact_id": 3574',
#   'name': ' "name": "Werner Kallert"',
#   'email': ' "email": "werner.kallert@gmail.com"}'},
#  {'contact_id': '{"contact_id": 6063',
#   'name': ' "name": "Lore Delaunay"',
#   'email': ' "email": "lore.delaunay@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 2404',
#   'name': ' "name": "Enzio Campos"',
#   'email': ' "email": "enzio.campos@tim.it"}'},
#  {'contact_id': '{"contact_id": 2705',
#   'name': ' "name": "Walther Duarte"',
#   'email': ' "email": "walther.duarte@web.de"}'},
#  {'contact_id': '{"contact_id": 5059',
#   'name': ' "name": "Adelgunde Trevisan"',
#   'email': ' "email": "adelgunde.trevisan@gmail.com"}'},
#  {'contact_id': '{"contact_id": 5466',
#   'name': ' "name": "Thierry Schwartz"',
#   'email': ' "email": "thierry.schwartz@travaglio.net"}'},
#  {'contact_id': '{"contact_id": 5821',
#   'name': ' "name": "Katie Andersen"',
#   'email': ' "email": "katie.andersen@haney.com.au"}'},
#  {'contact_id': '{"contact_id": 5385',
#   'name': ' "name": "Kathy Zamorani"',
#   'email': ' "email": "kathy.zamorani@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 3506',
#   'name': ' "name": "Giuseppina Tanguy"',
#   'email': ' "email": "giuseppina.tanguy@wanadoo.fr"}'},
#  {'contact_id': '{"contact_id": 5427',
#   'name': ' "name": "Jack Klapp"',
#   'email': ' "email": "jack.klapp@hotmail.com.au"}'},
#  {'contact_id': '{"contact_id": 6142',
#   'name': ' "name": "Tom Leconte"',
#   'email': ' "email": "tom.leconte@woods-johnson.com"}'},
#  {'contact_id': '{"contact_id": 2873',
#   'name': ' "name": "Bonnie Cignaroli"',
#   'email': ' "email": "bonnie.cignaroli@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 3916',
#   'name': ' "name": "Danny Farrell"',
#   'email': ' "email": "danny.farrell@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 1687',
#   'name': ' "name": "Fiorenzo Bauer"',
#   'email': ' "email": "fiorenzo.bauer@gmail.com"}'},
#  {'contact_id': '{"contact_id": 1542',
#   'name': ' "name": "Randy Alfieri"',
#   'email': ' "email": "randy.alfieri@verri.org"}'},
#  {'contact_id': '{"contact_id": 3087',
#   'name': ' "name": "Tim Bradley"',
#   'email': ' "email": "tim.bradley@schlosser.de"}'},
#  {'contact_id': '{"contact_id": 3857',
#   'name': ' "name": "Yves Mendez"',
#   'email': ' "email": "yves.mendez@gmail.com"}'},
#  {'contact_id': '{"contact_id": 5921',
#   'name': ' "name": "Raffaella Esquivel"',
#   'email': ' "email": "raffaella.esquivel@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3144',
#   'name': ' "name": "Lawrence Vasari"',
#   'email': ' "email": "lawrence.vasari@castillo.edu"}'},
#  {'contact_id': '{"contact_id": 2676',
#   'name': ' "name": "Sam Adams"',
#   'email': ' "email": "sam.adams@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 3646',
#   'name': ' "name": "Mirco Nicolini"',
#   'email': ' "email": "mirco.nicolini@blin.net"}'},
#  {'contact_id': '{"contact_id": 1321',
#   'name': ' "name": "Graham Bajardi"',
#   'email': ' "email": "graham.bajardi@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 1399',
#   'name': ' "name": "Luc Quinn"',
#   'email': ' "email": "luc.quinn@walker.com"}'},
#  {'contact_id': '{"contact_id": 3169',
#   'name': ' "name": "Stella Ullrich"',
#   'email': ' "email": "stella.ullrich@hotmail.com.au"}'},
#  {'contact_id': '{"contact_id": 2058',
#   'name': ' "name": "Calcedonio Remy"',
#   'email': ' "email": "calcedonio.remy@edwards-benton.com"}'},
#  {'contact_id': '{"contact_id": 1300',
#   'name': ' "name": "Nanni Almaraz"',
#   'email': ' "email": "nanni.almaraz@martin.com"}'},
#  {'contact_id': '{"contact_id": 2075',
#   'name': ' "name": "Pascual Corradi"',
#   'email': ' "email": "pascual.corradi@lopez.net.au"}'},
#  {'contact_id': '{"contact_id": 2984',
#   'name': ' "name": "Kristi Grant"',
#   'email': ' "email": "kristi.grant@yahoo.co.uk"}'},
#  {'contact_id': '{"contact_id": 4768',
#   'name': ' "name": "Manuel Gracia"',
#   'email': ' "email": "manuel.gracia@trussardi.eu"}'},
#  {'contact_id': '{"contact_id": 3682',
#   'name': ' "name": "Gionata Hussain"',
#   'email': ' "email": "gionata.hussain@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 5901',
#   'name': ' "name": "Maria Nguyen"',
#   'email': ' "email": "maria.nguyen@hernadez.com"}'},
#  {'contact_id': '{"contact_id": 3540',
#   'name': ' "name": "Leon Baker"',
#   'email': ' "email": "leon.baker@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 2225',
#   'name': ' "name": "Gianmarco Alcaraz"',
#   'email': ' "email": "gianmarco.alcaraz@zacchia.net"}'},
#  {'contact_id': '{"contact_id": 1485',
#   'name': ' "name": "Derrick Little"',
#   'email': ' "email": "derrick.little@small.org"}'},
#  {'contact_id': '{"contact_id": 5343',
#   'name': ' "name": "Terry Ramirez"',
#   'email': ' "email": "terry.ramirez@hotmail.co.uk"}'},
#  {'contact_id': '{"contact_id": 5594',
#   'name': ' "name": "Katarina Clarke"',
#   'email': ' "email": "katarina.clarke@hotmail.com.au"}'},
#  {'contact_id': '{"contact_id": 2482',
#   'name': ' "name": "Leila Washington"',
#   'email': ' "email": "leila.washington@gmail.com"}'},
#  {'contact_id': '{"contact_id": 2706',
#   'name': ' "name": "Mirko Townsend"',
#   'email': ' "email": "mirko.townsend@schmitt.com"}'},
#  {'contact_id': '{"contact_id": 4861',
#   'name': ' "name": "Randall Connolly"',
#   'email': ' "email": "randall.connolly@jovinelli-castelli.com"}'},
#  {'contact_id': '{"contact_id": 2961',
#   'name': ' "name": "Pia Burgess"',
#   'email': ' "email": "pia.burgess@proyectos.org"}'},
#  {'contact_id': '{"contact_id": 3043',
#   'name': ' "name": "Justine Mancini"',
#   'email': ' "email": "justine.mancini@tiscali.it"}'},
#  {'contact_id': '{"contact_id": 6103',
#   'name': ' "name": "Reynaldo Wagenknecht"',
#   'email': ' "email": "reynaldo.wagenknecht@faure.com"}'},
#  {'contact_id': '{"contact_id": 4708',
#   'name': ' "name": "Toni Magrassi"',
#   'email': ' "email": "toni.magrassi@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4395',
#   'name': ' "name": "Patrizio Cisneros"',
#   'email': ' "email": "patrizio.cisneros@martinez.edu.au"}'},
#  {'contact_id': '{"contact_id": 4912',
#   'name': ' "name": "Durante Lindner"',
#   'email': ' "email": "durante.lindner@picard.fr"}'},
#  {'contact_id': '{"contact_id": 2030',
#   'name': ' "name": "Rosl Lamborghini"',
#   'email': ' "email": "rosl.lamborghini@hiller.net"}'},
#  {'contact_id': '{"contact_id": 5235',
#   'name': ' "name": "Ugo Harrison"',
#   'email': ' "email": "ugo.harrison@morley-chapman.co.uk"}'},
#  {'contact_id': '{"contact_id": 5001',
#   'name': ' "name": "Isidor Carpenter"',
#   'email': ' "email": "isidor.carpenter@chauvin.com"}'},
#  {'contact_id': '{"contact_id": 4093',
#   'name': ' "name": "Marie Zoppetto"',
#   'email': ' "email": "marie.zoppetto@kallert.de"}'},
#  {'contact_id': '{"contact_id": 2576',
#   'name': ' "name": "Branko Chambers"',
#   'email': ' "email": "branko.chambers@ifrance.com"}'},
#  {'contact_id': '{"contact_id": 6122',
#   'name': ' "name": "Alan Pineda"',
#   'email': ' "email": "alan.pineda@proyectos.info"}'},
#  {'contact_id': '{"contact_id": 2813',
#   'name': ' "name": "Carmen Oestrovsky"',
#   'email': ' "email": "carmen.oestrovsky@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3737',
#   'name': ' "name": "Shane Fernandez"',
#   'email': ' "email": "shane.fernandez@hotmail.de"}'},
#  {'contact_id': '{"contact_id": 2803',
#   'name': ' "name": "Debbie Guilbert"',
#   'email': ' "email": "debbie.guilbert@berg.edu"}'},
#  {'contact_id': '{"contact_id": 5508',
#   'name': ' "name": "Vito Dossi"',
#   'email': ' "email": "vito.dossi@hotmail.co.uk"}'},
#  {'contact_id': '{"contact_id": 3850',
#   'name': ' "name": "Evan Schacht"',
#   'email': ' "email": "evan.schacht@price.com"}'},
#  {'contact_id': '{"contact_id": 4220',
#   'name': ' "name": "Mandy Weston"',
#   'email': ' "email": "mandy.weston@free.fr"}'},
#  {'contact_id': '{"contact_id": 4532',
#   'name': ' "name": "Paulo Zito"',
#   'email': ' "email": "paulo.zito@nelson.biz"}'},
#  {'contact_id': '{"contact_id": 6013',
#   'name': ' "name": "Alberto Girschner"',
#   'email': ' "email": "alberto.girschner@laboratorios.com"}'},
#  {'contact_id': '{"contact_id": 3396',
#   'name': ' "name": "Giacomo Bouvet"',
#   'email': ' "email": "giacomo.bouvet@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4401',
#   'name': ' "name": "Ehrentraud Puga"',
#   'email': ' "email": "ehrentraud.puga@laboratorios.com"}'},
#  {'contact_id': '{"contact_id": 2981',
#   'name': ' "name": "Cristian Hale"',
#   'email': ' "email": "cristian.hale@hotmail.co.uk"}'},
#  {'contact_id': '{"contact_id": 4467',
#   'name': ' "name": "Lilija Charles"',
#   'email': ' "email": "lilija.charles@gmail.com"}'},
#  {'contact_id': '{"contact_id": 1377',
#   'name': ' "name": "Albert Legendre"',
#   'email': ' "email": "albert.legendre@lee.com"}'},
#  {'contact_id': '{"contact_id": 5036',
#   'name': ' "name": "Marisa Renaud"',
#   'email': ' "email": "marisa.renaud@smith.org"}'},
#  {'contact_id': '{"contact_id": 5761',
#   'name': ' "name": "Sharon Diallo"',
#   'email': ' "email": "sharon.diallo@gmail.com"}'},
#  {'contact_id': '{"contact_id": 3699',
#   'name': ' "name": "Eduardo Delattre"',
#   'email': ' "email": "eduardo.delattre@lynch.net.au"}'},
#  {'contact_id': '{"contact_id": 4519',
#   'name': ' "name": "Bernadette Wang"',
#   'email': ' "email": "bernadette.wang@gmail.com"}'},
#  {'contact_id': '{"contact_id": 5395',
#   'name': ' "name": "Dina Gibbons"',
#   'email': ' "email": "dina.gibbons@brewer.net"}'},
#  {'contact_id': '{"contact_id": 3057',
#   'name': ' "name": "Clara Armstrong"',
#   'email': ' "email": "clara.armstrong@vodafone.it"}'},
#  {'contact_id': '{"contact_id": 2741',
#   'name': ' "name": "Elliott Herrmann"',
#   'email': ' "email": "elliott.herrmann@hotmail.com.au"}'},
#  {'contact_id': '{"contact_id": 1675',
#   'name': ' "name": "Graziella Vidal"',
#   'email': ' "email": "graziella.vidal@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 2712',
#   'name': ' "name": "Francisca Becerra"',
#   'email': ' "email": "francisca.becerra@young.com.au"}'},
#  {'contact_id': '{"contact_id": 4527',
#   'name': ' "name": "Edeltrud Boyer"',
#   'email': ' "email": "edeltrud.boyer@outlook.com"}'},
#  {'contact_id': '{"contact_id": 1722',
#   'name': ' "name": "Julian Noble"',
#   'email': ' "email": "julian.noble@hill.org.au"}'},
#  {'contact_id': '{"contact_id": 4330',
#   'name': ' "name": "Christophe Bohnbach"',
#   'email': ' "email": "christophe.bohnbach@ifrance.com"}'},
#  {'contact_id': '{"contact_id": 5219',
#   'name': ' "name": "Ippazio Angulo"',
#   'email': ' "email": "ippazio.angulo@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 4997',
#   'name': ' "name": "Grace Kroker"',
#   'email': ' "email": "grace.kroker@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 2239',
#   'name': ' "name": "Jared Ferguson"',
#   'email': ' "email": "jared.ferguson@roberts.com"}'},
#  {'contact_id': '{"contact_id": 4587',
#   'name': ' "name": "Virginie McLean"',
#   'email': ' "email": "virginie.mclean@yahoo.com"}'},
#  {'contact_id': '{"contact_id": 4113',
#   'name': ' "name": "Mason Potter"',
#   'email': ' "email": "mason.potter@gmail.com"}'},
#  {'contact_id': '{"contact_id": 4762',
#   'name': ' "name": "Aaron Anaya"',
#   'email': ' "email": "aaron.anaya@hotmail.com.au"}'},
#  {'contact_id': '{"contact_id": 5242',
#   'name': ' "name": "Leah Ornelas"',
#   'email': ' "email": "leah.ornelas@gmail.com"}'},
#  {'contact_id': '{"contact_id": 5765',
#   'name': ' "name": "Harald Roy"',
#   'email': ' "email": "harald.roy@web.de"}'},
#  {'contact_id': '{"contact_id": 2185',
#   'name': ' "name": "Micaela Martel"',
#   'email': ' "email": "micaela.martel@hotmail.com"}'},
#  {'contact_id': '{"contact_id": 5500',
#   'name': ' "name": "Vincentio Sanders"',
#   'email': ' "email": "vincentio.sanders@voila.fr"}'},
#  {'contact_id': '{"contact_id": 3494',
#   'name': ' "name": "Bettina Norbiato"',
#   'email': ' "email": "bettina.norbiato@allen-lutz.org"}'},
#  {'contact_id': '{"contact_id": 3924',
#   'name': ' "name": "Julio Renner"',
#   'email': ' "email": "julio.renner@industrias.net"}'},
#  {'contact_id': '{"contact_id": 3521',
#   'name': ' "name": "Jelena Stiffel"',
#   'email': ' "email": "jelena.stiffel@trupp.de"}'},
#  {'contact_id': '{"contact_id": 5262',
#   'name': ' "name": "Guadalupe Munoz"',
#   'email': ' "email": "guadalupe.munoz@murray-hamilton.com.au"}'},
#  {'contact_id': '{"contact_id": 3684',
#   'name': ' "name": "Whitney Noack"',
#   'email': ' "email": "whitney.noack@laboratorios.org"}'},
#  {'contact_id': '{"contact_id": 5784',
#   'name': ' "name": "Gelsomina Migliaccio"',
#   'email': ' "email": "gelsomina.migliaccio@junk.com"}'},
#  {'contact_id': '{"contact_id": 1498',
#   'name': ' "name": "Evangelista Pereira"',
#   'email': ' "email": "evangelista.pereira@thompson-peterson.biz"}'},
#  {'contact_id': '{"contact_id": 6073',
#   'name': ' "name": "Gareth Comolli"',
#   'email': ' "email": "gareth.comolli@tiscali.fr"}'},
#  {'contact_id': '{"contact_id": 4939',
#   'name': ' "name": "Michelangelo Hess"',
#   'email': ' "email": "michelangelo.hess@bouygtel.fr"}'}]

# %%
# Create a contact_info DataFrame and add each list of values, i.e., each row 
# to the 'contact_id', 'name', 'email' columns.

# %%
# Check the datatypes of each column.

# %%
# Create a "first"name" and "last_name" column with the first and last names from the "name" column. 


# Drop the contact_name column

# %%
# Reorder the columns

# %%
# Check the datatypes a final time before exporting as a CSV file.

# %%
# Export the DataFrame as a CSV file. 
# df.to_csv("contacts.csv", index=False)

# %% [markdown]
# ### Use regex to extract the contact data.

# %%
pd.set_option('max_colwidth', 400)
contact_info_df.head()
# Out:
#             contact_id                          name  \
# 0  {"contact_id": 4661     "name": "Cecilia Velasco"
# 1  {"contact_id": 3765       "name": "Mariana Ellis"
# 2  {"contact_id": 4187         "name": "Sofie Woods"
# 3  {"contact_id": 4941   "name": "Jeanette Iannotti"
# 4  {"contact_id": 2199      "name": "Samuel Sorgatz"
#
#                                        email
# 0   "email": "cecilia.velasco@rodrigues.fr"}
# 1        "email": "mariana.ellis@rossi.org"}
# 2        "email": "sofie.woods@riviere.com"}
# 3    "email": "jeanette.iannotti@yahoo.com"}
# 4       "email": "samuel.sorgatz@gmail.com"}

# %%
# Extract the four-digit contact ID number.
print(contact_info_df['contact_id'])
# Out:
# 0      {"contact_id": 4661
# 1      {"contact_id": 3765
# 2      {"contact_id": 4187
# 3      {"contact_id": 4941
# 4      {"contact_id": 2199
#               ...
# 995    {"contact_id": 3684
# 996    {"contact_id": 5784
# 997    {"contact_id": 1498
# 998    {"contact_id": 6073
# 999    {"contact_id": 4939
# Name: contact_id, Length: 1000, dtype: object

# %%
# Check the datatypes
df.dtypes
# Out:
# contact_id    object
# name          object
# email         object
# dtype: object

# %%
# Convert the "contact_id" column to an int64 data type.
contact_info_df["contact_id"] = contact_info_df["contact_id"].astype(object).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/q8/9lvq76b16ydd57m7bvxtts9m0000gn/T/ipykernel_2280/1726586267.py in <module>
#       1 # Convert the "contact_id" column to an int64 data type.
# ----> 2 contact_info_df["contact_id"] = contact_info_df["contact_id"].astype(object).astype(int)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '{"contact_id": 4661'

# %%
# Extract the name of the contact and add it to a new column.

# %%
# Extract the email from the contacts and add the values to a new column.

# %%
# Create a copy of the contact_info_df with the 'contact_id', 'name', 'email' columns.

# %%
# Create a "first"name" and "last_name" column with the first and last names from the "name" column. 


# Drop the contact_name column

# %%
# Reorder the columns

# %%
# Check the datatypes one more time before exporting as a CSV file.
